# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 1. Basic shape and types
train = pd.read_csv("../data/raw/train.csv")
test  = pd.read_csv("../data/raw/test.csv")

# 1. Basic shape and types
print(train.shape)       # e.g., (100000, 18)
print(train.dtypes)
print(train.head())
# Out:
# (577347, 12)
# id                     int64
# alpha                float64
# delta                float64
# u                    float64
# g                    float64
# r                    float64
# i                    float64
# z                    float64
# redshift             float64
# spectral_type            str
# galaxy_population        str
# class                    str
# dtype: object
#    id       alpha      delta          u          g          r          i  \
# 0   0  147.734256  16.959273  25.472123  21.895559  20.357926  19.257113
# 1   1  127.988677  32.346716  20.778509  19.087062  17.587208  17.226067
# 2   2  179.792648  35.344843  21.035203  21.079128  21.171840  20.582629
# 3   3  225.818295  48.569421  23.305056  21.050736  19.017754  18.365658
# 4   4  141.836135  19.342852  21.703158  19.471680  18.234449  17.899447
#
#            z  redshift spectral_type galaxy_population   class
# 0  18.621057  0.408982             M      Red_Sequence  GALAXY
# ...

# %%
print(test.shape)
# Out:
# (247435, 11)

# %%
# Save first 1000 rows of test data to analyse.csv
analyse_df = train.head(1000)
analyse_df.to_csv("../data/raw/analyse.csv", index=False)
print(f"Saved {len(analyse_df)} rows to ../data/raw/analyse.csv")
# Out:
# Saved 1000 rows to ../data/raw/analyse.csv
